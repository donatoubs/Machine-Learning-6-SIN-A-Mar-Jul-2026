# %%
# import pandas and assign it to the variable 'pd'
import pandas as pd

# we often import NumPy numerical python with pandas
import numpy as np

#load matplotlib for plotting later in the workshop
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import csv
unemployment = pd.read_csv('/workspaces/Machine-Learning-6-SIN-A-Mar-Jul-2026/data/country_total.csv')

# %%
# type unemployment
type(unemployment)
# Out:
# pandas.DataFrame

# %%
# read the 5 rows
unemployment.head()
# Out:
#   country seasonality    month  unemployment  unemployment_rate
# 0      at         nsa  1993.01        171000                4.5
# 1      at         nsa  1993.02        175000                4.6
# 2      at         nsa  1993.03        166000                4.4
# 3      at         nsa  1993.04        157000                4.1
# 4      at         nsa  1993.05        147000                3.9

# %%
# Read the size of the DataFrame
unemployment.shape
# Out:
# (20796, 5)

# %%
# Read the total columns of csv
unemployment.columns
# Out:
# Index(['country', 'seasonality', 'month', 'unemployment', 'unemployment_rate'], dtype='str')

# %%
# Read the type data of columns
unemployment.dtypes
# Out:
# country                  str
# seasonality              str
# month                float64
# unemployment           int64
# unemployment_rate    float64
# dtype: object

# %%
# Describe the summary about the table
unemployment.describe()
# Out:
#               month  unemployment  unemployment_rate
# count  20796.000000  2.079600e+04       19851.000000
# mean    1999.401290  7.900818e+05           8.179764
# std        7.483751  1.015280e+06           3.922533
# min     1983.010000  2.000000e+03           1.100000
# 25%     1994.090000  1.400000e+05           5.200000
# 50%     2001.010000  3.100000e+05           7.600000
# 75%     2006.010000  1.262250e+06          10.000000
# max     2010.120000  4.773000e+06          20.900000

# %%
my_list = ['a', 'b', 'c', 'd', 'e', 'f']

# %%
#Print the last 4 items
my_list[2:]
# Out:
# ['c', 'd', 'e', 'f']

# %%
my_list[len(my_list)-4:]
# Out:
# ['c', 'd', 'e', 'f']

# %%
import pandas as pd
country = pd.read_csv('/workspaces/Machine-Learning-6-SIN-A-Mar-Jul-2026/data/countries.csv')

# %%
country.describe()
# Out:
#         latitude  longitude
# count  30.000000  30.000000
# mean   49.092609  14.324579
# std     7.956624  11.257010
# min    35.129141  -8.239122
# 25%    43.230916   6.979186
# 50%    49.238087  14.941462
# 75%    54.090400  23.351690
# max    64.950159  35.439795

# %%
country.columns
# Out:
# Index(['country', 'google_country_code', 'country_group', 'name_en', 'name_fr',
#        'name_de', 'latitude', 'longitude'],
#       dtype='str')

# %%
country.shape
# Out:
# (30, 8)

# %%
country.dtypes
# Out:
# country                    str
# google_country_code        str
# country_group              str
# name_en                    str
# name_fr                    str
# name_de                    str
# latitude               float64
# longitude              float64
# dtype: object

# %%
country.info
# Out:
# <bound method DataFrame.info of    country google_country_code country_group  \
# 0       at                  AT            eu
# 1       be                  BE            eu
# 2       bg                  BG            eu
# 3       hr                  HR        non-eu
# 4       cy                  CY            eu
# 5       cz                  CZ            eu
# 6       dk                  DK            eu
# 7       ee                  EE            eu
# 8       fi                  FI            eu
# 9       fr                  FR            eu
# 10      de                  DE            eu
# 11      gr                  GR            eu
# 12      hu                  HU            eu
# 13      ie                  IE            eu
# 14      it                  IT            eu
# 15      lv                  LV            eu
# 16      lt                  LT            eu
# 17      lu                  LU            eu
# 18      mt                  MT            eu
# ...

# %%
#Search by name of columns and row
country.loc[3,'country_group']
# Out:
# 'non-eu'

# %%
#Search rows
country.loc[:4,:]
# Out:
#   country google_country_code country_group   name_en   name_fr     name_de  \
# 0      at                  AT            eu   Austria  Autriche  Österreich
# 1      be                  BE            eu   Belgium  Belgique     Belgien
# 2      bg                  BG            eu  Bulgaria  Bulgarie   Bulgarien
# 3      hr                  HR        non-eu   Croatia   Croatie    Kroatien
# 4      cy                  CY            eu    Cyprus    Chypre      Zypern
#
#     latitude  longitude
# 0  47.696554  13.345980
# 1  50.501045   4.476674
# 2  42.725674  25.482322
# 3  44.746643  15.340844
# 4  35.129141  33.428682

# %%
#Search all rows but 
country.iloc[:,:-4]
# Out:
#    country google_country_code country_group  \
# 0       at                  AT            eu
# 1       be                  BE            eu
# 2       bg                  BG            eu
# 3       hr                  HR        non-eu
# 4       cy                  CY            eu
# 5       cz                  CZ            eu
# 6       dk                  DK            eu
# 7       ee                  EE            eu
# 8       fi                  FI            eu
# 9       fr                  FR            eu
# 10      de                  DE            eu
# 11      gr                  GR            eu
# 12      hu                  HU            eu
# 13      ie                  IE            eu
# 14      it                  IT            eu
# 15      lv                  LV            eu
# 16      lt                  LT            eu
# 17      lu                  LU            eu
# 18      mt                  MT            eu
# 19      nl                  NL            eu
# ...

# %%
#Select rows from 20 until 25
test = country.loc[20:25, :]
test
# Out:
#    country google_country_code country_group   name_en    name_fr    name_de  \
# 20      no                  NO        non-eu    Norway    Norvège   Norwegen
# 21      pl                  PL            eu    Poland    Pologne      Polen
# 22      pt                  PT            eu  Portugal   Portugal   Portugal
# 23      ro                  RO            eu   Romania   Roumanie   Rumänien
# 24      sk                  SK            eu  Slovakia  Slovaquie   Slowakei
# 25      si                  SI            eu  Slovenia   Slovénie  Slowenien
#
#      latitude  longitude
# 20  64.556460  12.665766
# 21  51.918907  19.134334
# 22  39.558069  -7.844941
# 23  45.942611  24.990152
# 24  48.672644  19.700032
# 25  46.149259  14.986617

# %%
#Filter the DataFrame to show only rows non-eu
test[test['country_group'] == 'non-eu']
# Out:
#    country google_country_code country_group name_en  name_fr   name_de  \
# 20      no                  NO        non-eu  Norway  Norvège  Norwegen
#
#     latitude  longitude
# 20  64.55646  12.665766

# %%
#Filter the DataFrame country to whow only rows > 25
country[country['longitude']>25]
# Out:
#    country google_country_code country_group   name_en   name_fr    name_de  \
# 2       bg                  BG            eu  Bulgaria  Bulgarie  Bulgarien
# 4       cy                  CY            eu    Cyprus    Chypre     Zypern
# 7       ee                  EE            eu   Estonia   Estonie    Estland
# 8       fi                  FI            eu   Finland  Finlande   Finnland
# 28      tr                  TR        non-eu    Turkey   Turquie     Türkei
#
#      latitude  longitude
# 2   42.725674  25.482322
# 4   35.129141  33.428682
# 7   58.592469  25.806950
# 8   64.950159  26.067564
# 28  38.952942  35.439795
